# %% [markdown]
# # Feature Extraction

# %%
import os
import librosa
import torch
import numpy as np
import pandas as pd
import re
import crepe  
import soundfile as sf

# %%
# === Paths ===
INPUT_DIR = r"C:\College\Subjects\Sem 6\Speech Processing\Project\Dataset\Balanced"
OUTPUT_DIR = r"C:\College\Subjects\Sem 6\Speech Processing\Project\Dataset\Features"
SR = 16000

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# === Helper Functions ===

def hz_to_cents(pitch_hz, tonic_hz):
    """Convert frequency (Hz) to cents relative to tonic."""
    return 1200 * np.log2(pitch_hz / tonic_hz)

def estimate_tonic_crepe(audio, sr=16000):
    """Estimate tonic using pitch histogram from CREPE output."""
    time, frequency, confidence, activation = crepe.predict(
        audio, sr, viterbi=True, step_size=10
    )
    freq_confident = frequency[confidence > 0.5]
    if len(freq_confident) == 0:
        return 1.0  # Avoid log(0) errors later
    hist, bins = np.histogram(freq_confident, bins=np.linspace(50, 1000, 500))
    tonic_hz = bins[np.argmax(hist)]
    return tonic_hz

def extract_pitch_features(audio, sr=16000, tonic=None):
    time, frequency, confidence, activation = crepe.predict(
        audio, sr, viterbi=True, step_size=10
    )

    # Filter low-confidence frames
    frequency[confidence < 0.5] = np.nan
    pitch_cents = hz_to_cents(frequency, tonic)

    # Interpolate missing (nan) values
    pitch_cents = pd.Series(pitch_cents).interpolate().fillna(method='bfill').fillna(method='ffill').values

    # Derivatives (velocity, acceleration)
    velocity = np.gradient(pitch_cents)
    acceleration = np.gradient(velocity)

    # Stack into matrix
    features = np.stack([pitch_cents, velocity, acceleration], axis=1)
    return time, features

# === Main Processing Loop ===

for raga_folder in os.listdir(INPUT_DIR):
    raga_path = os.path.join(INPUT_DIR, raga_folder)
    if not os.path.isdir(raga_path):
        continue

    output_raga_path = os.path.join(OUTPUT_DIR, raga_folder)
    os.makedirs(output_raga_path, exist_ok=True)

    for file in os.listdir(raga_path):
        if not file.endswith(".wav"):
            continue

        file_path = os.path.join(raga_path, file)
        print(f" Processing: {file}")

        try:
            # Load audio
            audio, _ = librosa.load(file_path, sr=SR, mono=True)

            # === Tonic Handling ===
            tonic_match = re.search(r'tonic=(\d+\.\d+)', file)
            if tonic_match:
                tonic_hz = float(tonic_match.group(1))
                print(f" Tonic found in filename: {tonic_hz} Hz")
            else:
                tonic_hz = estimate_tonic_crepe(audio, sr=SR)
                print(f" Estimated tonic: {tonic_hz:.2f} Hz")

            # === Feature Extraction ===
            time, feature_matrix = extract_pitch_features(audio, sr=SR, tonic=tonic_hz)

            # === Save Features ===
            out_name = os.path.splitext(file)[0] + "_features.npy"
            np.save(os.path.join(output_raga_path, out_name), feature_matrix)

            print(f" Saved features: {feature_matrix.shape} → {out_name}")

        except Exception as e:
            print(f" Error processing {file}: {e}")

print("\n All pitch-based features extracted and saved :)")
# Out:
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg0.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 6s 26ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg0_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg1.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 29ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg1_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg10.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg10_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg100.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg100_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg101.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 17ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg101_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg102.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg102_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg103.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 20ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg103_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg104.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg104_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg105.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg105_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg106.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg106_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg107.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg107_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg108.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg108_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg109.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg109_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg11.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg11_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg110.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg110_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg111.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg111_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg112.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg112_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg113.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 17ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg113_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg114.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 17ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg114_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg115.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg115_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg116.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg116_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg117.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg117_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg118.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg118_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg119.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg119_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg12.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg12_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg120.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg120_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg121.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg121_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg122.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg122_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg123.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg123_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg124.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg124_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg125.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg125_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg126.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg126_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg127.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg127_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg128.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg128_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg129.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg129_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg13.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 20ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg13_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg14.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg14_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg15.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg15_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg16.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg16_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg17.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg17_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg18.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg18_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg19.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg19_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg2.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg2_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg20.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg20_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg21.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg21_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg22.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg22_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg23.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg23_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg24.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg24_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg25.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg25_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg26.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg26_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg27.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg27_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg28.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg28_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg29.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg29_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg3.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 20ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg3_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg30.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg30_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg31.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg31_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg32.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg32_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg33.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg33_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg34.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg34_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg35.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg35_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg36.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg36_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg37.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg37_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg38.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg38_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg39.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg39_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg4.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg4_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg40.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg40_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg41.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg41_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg42.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg42_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg43.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg43_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg44.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg44_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg45.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg45_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg46.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg46_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg47.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg47_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg48.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg48_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg49.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg49_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg5.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg5_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg50.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg50_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg51.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg51_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg52.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg52_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg53.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg53_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg54.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg54_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg55.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg55_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg56.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg56_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg57.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg57_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg58.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg58_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg59.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg59_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg6.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg6_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg60.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg60_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg61.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg61_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg62.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg62_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg63.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg63_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg64.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg64_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg65.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg65_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg66.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg66_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg67.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg67_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg68.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg68_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg69.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg69_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg7.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg7_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg70.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg70_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg71.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg71_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg72.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg72_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg73.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg73_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg74.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg74_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg75.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg75_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg76.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg76_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg77.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg77_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg78.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg78_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg79.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg79_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg8.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg8_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg80.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg80_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg81.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg81_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg82.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg82_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg83.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg83_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg84.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg84_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg85.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg85_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg86.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg86_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg87.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg87_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg88.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg88_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg89.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg89_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg9.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg9_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg90.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg90_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg91.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg91_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg92.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg92_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg93.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg93_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg94.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg94_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg95.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg95_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg96.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg96_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg97.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg97_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg98.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg98_features.npy
#  Processing: Thodi_5_trimmed_noise_tonic=129.96_seg99.wav
#  Tonic found in filename: 129.96 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_noise_tonic=129.96_seg99_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg0.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg0_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg1.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg1_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg10.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg10_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg100.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg100_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg101.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg101_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg102.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg102_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg103.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg103_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg104.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg104_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg105.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg105_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg106.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg106_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg107.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg107_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg108.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg108_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg109.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg109_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg11.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg11_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg110.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg110_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg111.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg111_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg112.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg112_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg113.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg113_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg114.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg114_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg115.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg115_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg116.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg116_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg117.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg117_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg118.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg118_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg119.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg119_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg12.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg12_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg120.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg120_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg121.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg121_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg122.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg122_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg123.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg123_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg124.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg124_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg125.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg125_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg126.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg126_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg127.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg127_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg128.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg128_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg129.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg129_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg13.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg13_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg14.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg14_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg15.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg15_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg16.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg16_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg17.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg17_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg18.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg18_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg19.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg19_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg2.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg2_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg20.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg20_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg21.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg21_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg22.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg22_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg23.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg23_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg24.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg24_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg25.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg25_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg26.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg26_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg27.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg27_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg28.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 18ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg28_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg29.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg29_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg3.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg3_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg30.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg30_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg31.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg31_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg32.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg32_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg33.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg33_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg34.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg34_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg35.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg35_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg36.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg36_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg37.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg37_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg38.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg38_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg39.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg39_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg4.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg4_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg40.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg40_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg41.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg41_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg42.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg42_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg43.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg43_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg44.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg44_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg45.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg45_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg46.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg46_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg47.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg47_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg48.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg48_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg49.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg49_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg5.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg5_features.npy
#  Processing: Thodi_5_trimmed_pitch_tonic=147.09_seg50.wav
#  Tonic found in filename: 147.09 Hz
# 32/32 [==============================] - 1s 19ms/step
#  Saved features: (1001, 3) → Thodi_5_trimmed_pitch_tonic=147.09_seg50_features.npy
#
#  All pitch-based features extracted and saved :)
